# %%
import wget

# %%
filename=wget.download("https://storage.googleapis.com/mledu-datasets/mnist_train_small.csv") # -O /tmp/mnist_train_small.csv

# %%
filename
# Out:
# 'mnist_train_small (2).csv'

# %%
import sys
sys.path.append('/Users/rudyhofmeister/git/RudyDev/machine_learning/MNIST/')
import mnist
# Out:
# Training model...
# LogLoss error (on validation data):
#   period 00 : 16.52
#   period 01 : 11.37
#   period 02 : 11.29
#   period 03 : 7.93
#   period 04 : 8.34
#   period 05 : 7.41
#   period 06 : 6.44
#   period 07 : 5.79
#   period 08 : 5.82
#   period 09 : 6.67
# Model training finished.
# Final accuracy (on validation data): 0.81

# %%
import mnist_nn
# Out:
# Training model...
# LogLoss error (on validation data):
#   period 00 : 4.75
#   period 01 : 3.54
#   period 02 : 3.77
#   period 03 : 3.38
#   period 04 : 3.15
#   period 05 : 2.29
#   period 06 : 1.99
#   period 07 : 2.04
#   period 08 : 1.99
#   period 09 : 1.69
# Model training finished.
# Final accuracy (on validation data): 0.95
# Accuracy on test data: 0.95
